# %%
from Bio import Phylo

tree = Phylo.read("t.nwk", "newick")
Phylo.draw(tree)
Phylo.draw_ascii(tree)
# Out:
#  , MT276600.1
#  |
#  | MT276328.2
#  |
#  , MT106054.1
# _|
#  , LR882413.1
#  |
#  , MW079826.1
#  |
#  |     _________________ NC_004718.3
#  |____|
#  |    |                   ___________________________________ NC_048212.1
#  |    |__________________|
#  |                       |_______________________________________ NC_019843.3
#  |
#  , MW000350.1
#  |
#  | LR880580.1
#  |
#  | NC_045512.2
